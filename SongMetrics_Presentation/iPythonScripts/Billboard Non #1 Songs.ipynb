# %%
#8.3 Project Presentations for WASHSTL201809DATA3 by Group H - Cody Braun, Austen Manser and Bill Nash

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
top100df = pd.read_csv("../Resources/Feature_MergedDF.csv")
top100df.head()
# Out:
#                                        Title  \
# 0                                     "Yep!"
# 1                                       'Til
# 2                        ('til) I Kissed You
# 3  (A Ship Will Come) Ein Schiff Wird Kommen
# 4           (All of a Sudden) My Heart Sings
#
#                                         Artist  Peak_Position_x  \
# 0  Duane Eddy His Twangy Guitar And The Rebels               30
# 1                                   The Angels               14
# 2                          The Everly Brothers                4
# 3                                Lale Anderson               88
# 4                                    Paul Anka               15
#
#                   Song ID  Song Popularity  Acousticness  Danceability  \
# 0                     NaN              NaN           NaN           NaN
# 1  4xDL1E4h0s3gHADCG7EQBd              0.0        0.7250         0.508
# 2  0hA25gRi0Gh56Lb1wrud2Q              0.0        0.0231         0.704
# ...

# %%
top100filteredDF = top100df.dropna()
top100filteredDF.head()
len(top100filteredDF)
# Out:
# 20950

# %%
top100not1df = top100filteredDF.loc[top100filteredDF["Peak_Position_x"]>1,:]
len(top100not1df)
# Out:
# 20040

# %%
years = []
years = [x[:3]+"0" for x in top100not1df["Date"]]
#print(years)
top100not1df["Year"] = years
top100not1df.head()
# Out:
# C:\Users\codyb\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                               Title               Artist  Peak_Position_x  \
# 1                              'Til           The Angels               14
# 2               ('til) I Kissed You  The Everly Brothers                4
# 4  (All of a Sudden) My Heart Sings            Paul Anka               15
# 5                (Baby) Hully Gully         The Olympics               72
# 6           (Dance The) Mess Around       Chubby Checker               24
#
#                   Song ID  Song Popularity  Acousticness  Danceability  \
# 1  4xDL1E4h0s3gHADCG7EQBd              0.0        0.7250         0.508
# ...

# %%
top100not1df.to_csv("../Resources/Top100Not1_withDecade.csv", index=False, encoding="UTF-8")
